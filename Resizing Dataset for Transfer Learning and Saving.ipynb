# %% [markdown]
# <h2 align=center> Resizing Dataset for Transfer Learning and Saving</h2>

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import utils
import os

from tensorflow.keras.preprocessing.image import ImageDataGenerator

from IPython.display import SVG, Image
import tensorflow as tf
print("Tensorflow version:", tf.__version__)
# Out:
# Tensorflow version: 1.14.0

# %% [markdown]
# ### Plot Some Sample Images

# %%
utils.datasets.fer.plot_example_images(plt,"train/").show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import utils
import os

from tensorflow.keras.preprocessing.image import ImageDataGenerator

from IPython.display import SVG, Image
import tensorflow as tf
print("Tensorflow version:", tf.__version__)

#python dataset_resizer.py 224 train/ Resized_images/ lanczos
class Resizing:
	def __init__(self, img_size, flow_from_directory1,save_directory,algorithm):
		self.img_size = img_size
		self.batch_size = 1
		self.flow_from_directory1 = str(flow_from_directory1)
		self.save_to_directory = str(save_directory)
		self.algorithm=str(algorithm)
	def resizer(self):
		counter = 1
		datagen_train = ImageDataGenerator(horizontal_flip=False)
		train_generator = datagen_train.flow_from_directory(self.flow_from_directory1,target_size=(self.img_size,self.img_size),color_mode="rgb",batch_size=self.batch_size,shuffle=False,class_mode='categorical',save_to_dir=self.save_to_directory,save_prefix='img',save_format='png',subset=None,interpolation=self.algorithm)
		for i in train_generator:
			if counter > int(len(os.listdir(self.flow_from_directory1+ expression )))-1 :
				break
			else:
				counter+=1
# Out:
# Tensorflow version: 1.14.0

# %%
p1 = Resizing(224,"train/","Resized_images/","lanczos").resizer()
# Out:
# Found 16 images belonging to 1 classes.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-83730520490b> in <module>
# ----> 1 p1 = Resizing(224,"train/","Resized_images/","lanczos").resizer()
#
# <ipython-input-10-d44a65f0495c> in resizer(self)
#      24                 train_generator = datagen_train.flow_from_directory(self.flow_from_directory1,target_size=(self.img_size,self.img_size),color_mode="rgb",batch_size=self.batch_size,shuffle=False,class_mode='categorical',save_to_dir=self.save_to_directory,save_prefix='img',save_format='png',subset=None,interpolation=self.algorithm)
#      25                 for i in train_generator:
# ---> 26                         if counter > int(len(os.listdir(self.flow_from_directory1+ expression )))-1 :
#      27                                 break
#      28                         else:
#
# NameError: name 'expression' is not defined
